# %% [markdown]
# # 03 策略研究
#
# 策略信号与回测实验。

# %%
import sys
from pathlib import Path
ROOT = Path.cwd().parent
sys.path.insert(0, str(ROOT))

from src.strategy.cta import CTAStrategy
print(CTAStrategy(fast_period=10, slow_period=30))
